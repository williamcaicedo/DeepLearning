# %% [markdown]
# # Deep Learning
#
# ## Assignment 5
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Several things just happened. A vocabulary size 50000 was built with the most common words of the corpus. All the remaining words are labeled as "unknown"(UNK). To do so:
# - `count` is filled with the 49999 most common words and their frequencies.
# - Dictionary `dict` is populated with and entry for each word and its corresponding position in the original `words` string (using a trick with the lenght of the dictionary in each iteration of the `for` loop.
# - List `data` is populated with the index of each word which was just stored in `dict`. If a word was not part of the 49999 most common (it is not in the dictionary), it is considered as a unknown, so its index considered to be zero and a counter `unk_count` is incremented.
# - `count` first position is updated with the total count of unknowns.
# - A reverse dictionary (the values of the original `dict` now are the keys and viceversa - so keys are now the position of the word in the `words` string and values are the respective words) is created.

# %% [markdown]
# ### Word2Vec (Skipgram)
#
# Word2Vec is a way to learn a vector representation (embedding) for text.
#
# ![word2vec](word2vec.png)
#
#
# ![skipgram](skipgram.jpg)
#
# The idea behind skip-gram is to use every word of the corpus to predict the words next to it. This is motivated by the intuition that word meaning is conditioned by the context in which words are used. So if different words tend to occur in the same context, they probabbly are close semantically to each other (this is the distributional hypothesis). So skip-gram trains a linear classifier to do exactly that: Predict the words in the vicinity (skip window) of a word (skip word) using this word as its input. Although the classifier is Logistic Regression, an extra layer of weights is used (so we could say it is in fact a 2-layer neural network with a hidden layer that uses linear activation functions). This layer correspond to a weight matrix which is the embedding matrix. The number of neurons of this hidden layer (the number of columns of the weight matrix) defines the dimensionality of the embedding space.
#
# Why this works? It works because by training our classifier to predict words given surrounding ones, we force words that tend to appear in the same contexts (which by the distributional hypothesis we assume to have similar o related meanings) to have similar vector representations. For example, let's look at the words kid and boy. It is conceivable that such words appear in similar phrases (contexts), as "the kid is my child", or "the boy is my child". Now, according to skipgram those two phrases would generate training examples like (kid,child) and (boy,child). Given than we are predicting "child", the embeddings of both "kid" and "boy" will have to be similar to "child" (neurons work by cosine distance after all), and thus between themselves.
#
# The input words are represented as one-hot vectors (our code just did that, by creating a vector with the indexes of the most common words). Because of this in practical terms, the TensorFlow training code performs a lookup on the embedding weight matrix when a new input is presented to the model, since the result of multipliying a one-hot row vector to a matrix is one of the rows of the matrix.

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0 # this variable acts a a global pointer to the data array. 

def generate_batch_skipgram(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) # sliding window to be moved over the whole data array
  # fill the buffer with the first words from the current window (span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data) # modulo just in case we get to the end of the data array
  # we use // because we move slower on the data array than on the batch array, i.e, 
  # as i increases once (we advance one position in data[]), j increases 4 times
  # (we advance 4 positions in batch[]) given that we are repeating the skip_word <num_skip> times
  for i in range(batch_size // num_skips): 
    target = skip_window  # target label at the center of the buffer
    # this is to be filled with 1. the current skip word (we dont want to predict the skip 
    # word using the same skip word as input), and 2. with the words we have already used as labels
    targets_to_avoid = [ skip_window ] 
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1) # select randomly an unused word from the skip window
      targets_to_avoid.append(target)
      # the word in position skip_window is the word of the middle of the window (span), which is the 
      # prediction input, so we add it to the input list. i controls the batch and j the offset into the batch
      batch[i * num_skips + j] = buffer[skip_window] 
      labels[i * num_skips + j, 0] = buffer[target] # we add the label to be predicted
    # let's move the sliding window one word to the right
    buffer.append(data[data_index]) # push one in to the back of the queue, the first in the queue pops out
    data_index = (data_index + 1) % len(data)
  return batch, labels

# remember, data contains the keys (indexes of words the in original words string) of common 
# words in the reverse dictionary
print('data:', [reverse_dictionary[di] for di in data[:8]])

# some examples of skipgram datasets
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_skipgram(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # This method is used similar to fancy indexing in numpy. train_dataset is a list of indexes
  # representing the rows to be retrieved from the embeddings 2D tensor. The resulting rows are
  # the embedding vectors for each input word of the training batch. The vectors are concatenated
  # into a dense tensor of shape (batch_size x embedding_size)
  # just as if we had multiplied a bunch of one hot row vectors with the embedding matrix
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  # embed is a tensor with shape (batch_size x embedding_size)
  # weights is tensor with shape (vocabulary_size x embedding_size)
  # so I guess what happens below is that embed gets transposed so the shapes match for multiplication
  # output = softmax_weights * embed.T + softmax_biases
  # output is a tensor with shape (vocabulary_size x batch size), i.e. one output column 
  # (probability distribution over the vocabulary) per input word
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_skipgram(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.972099
# Nearest to system: butler, resources, uninteresting, maroon, solver, assignments, whispered, causal,
# Nearest to a: jaime, empiricism, incisors, palo, chogm, micros, hearn, felons,
# Nearest to were: perdition, caribou, palomar, la, baron, himalayas, plagiarized, forbid,
# Nearest to two: pallas, guesses, merchants, binge, complicate, folkestone, entire, assurance,
# Nearest to or: countering, schroeder, mommy, man, bacharach, noblemen, michele, geothermal,
# Nearest to that: mediums, vt, dissimilar, hay, submerged, gdansk, sanger, reproducible,
# Nearest to their: lynx, ultrasound, explanatory, cameraman, tiki, mentats, simmered, bremerhaven,
# Nearest to into: ventricular, newcomers, kor, necessity, successes, cologne, unaids, tenerife,
# Nearest to but: clocks, averages, spate, steelers, mayfield, sedition, giuliani, bokken,
# Nearest to many: articulated, cones, hol, sutcliffe, ramp, secessionist, footing, repressing,
# Nearest to up: autumnal, thermochemistry, conceptually, tradeoff, enchantment, ganz, stormbringer, mina,
# Nearest to who: aquatic, postponed, bathtub, polly, mississippian, nicolau, penderecki, fishery,
# Nearest to on: keypad, conceptualization, dillinger, terrorism, turntables, highlanders, saimei, zone,
# Nearest to s: computer, gelling, piraeus, aedh, cloister, distributing, decimus, peshitta,
# Nearest to for: serialised, maitreya, kata, slime, knapp, golan, treeless, displacement,
# Nearest to as: gibbons, render, bodies, mil, snowmobile, maria, beatboxing, sseldorf,
# Average loss at step 2000: 4.365270
# Average loss at step 4000: 3.865283
# Average loss at step 6000: 3.785544
# Average loss at step 8000: 3.689118
# Average loss at step 10000: 3.611059
# Nearest to system: butler, resources, maroon, sequential, gorey, confusion, whispered, uninteresting,
# Nearest to a: the, orfeo, counted, incisors, any, hearn, his, malaysians,
# Nearest to were: are, was, is, have, had, be, oblivion, when,
# Nearest to two: four, three, five, eight, six, seven, nine, one,
# Nearest to or: and, purchases, s, than, medell, impairment, renal, literary,
# Nearest to that: which, disposed, it, commented, sternum, who, this, morum,
# Nearest to their: his, its, the, encyclopedist, this, any, her, waterfowl,
# Nearest to into: from, navigate, kor, ventricular, snowmobile, on, regarding, compaor,
# Nearest to but: spate, are, thirds, and, is, ertegun, you, hawkeye,
# Nearest to many: some, hol, composer, measurements, veer, reid, all, themselves,
# Nearest to up: tradeoff, autumnal, cession, arecibo, conceptually, thermochemistry, him, raaf,
# Nearest to who: he, which, also, counterculture, repackaged, acceleration, and, bathtub,
# Nearest to on: at, in, during, from, terrorism, dictatorships, within, bangs,
# Nearest to s: his, or, and, medell, aedh, blackboard, decimus, of,
# Nearest to for: with, treeless, of, prime, from, irritant, and, gundestrup,
# Nearest to as: by, treeless, elamites, backside, cadiz, runequest, after, with,
# Average loss at step 12000: 3.604919
# Average loss at step 14000: 3.572540
# Average loss at step 16000: 3.408554
# Average loss at step 18000: 3.457765
# Average loss at step 20000: 3.542819
# Nearest to system: resources, butler, sequential, alkene, maroon, gorey, confusion, ai,
# Nearest to a: the, incisors, or, thrax, nonexistence, this, no, any,
# Nearest to were: are, was, had, have, be, by, been, is,
# Nearest to two: three, five, four, six, eight, seven, one, nine,
# Nearest to or: and, than, a, maccabeus, apostles, nailed, like, tco,
# Nearest to that: which, this, but, disposed, who, it, also, however,
# Nearest to their: his, its, the, her, some, encyclopedist, any, cession,
# Nearest to into: from, regarding, on, by, through, in, compaor, courthouse,
# Nearest to but: however, and, does, that, although, is, lorry, which,
# Nearest to many: some, several, these, all, other, various, reid, themselves,
# Nearest to up: tradeoff, him, cession, conceptually, back, arecibo, endanger, autumnal,
# Nearest to who: he, which, they, also, and, then, often, that,
# Nearest to on: at, in, during, into, hol, categorized, terrorism, endeavours,
# Nearest to s: recordings, blackboard, computer, utah, tzow, brides, egalitarianism, tottenham,
# Nearest to for: using, and, of, in, paasikivi, serialised, prime, to,
# Nearest to as: mayonnaise, ideology, evidently, elamites, treeless, tal, atil, racetrack,
# Average loss at step 22000: 3.503733
# Average loss at step 24000: 3.488504
# Average loss at step 26000: 3.481180
# Average loss at step 28000: 3.481416
# Average loss at step 30000: 3.505046
# Nearest to system: resources, butler, theory, alkene, maroon, caldera, blocks, lauderdale,
# Nearest to a: any, the, no, ovum, memphis, halpin, nara, orfeo,
# Nearest to were: are, was, have, had, mom, been, be, including,
# Nearest to two: four, three, one, five, six, seven, eight, zero,
# Nearest to or: and, than, but, maccabeus, hart, oleg, ordaining, luton,
# Nearest to that: which, what, hamster, this, disposed, exterminated, morum, if,
# Nearest to their: its, his, her, the, some, any, ratites, these,
# Nearest to into: from, through, regarding, on, kor, courthouse, under, across,
# Nearest to but: however, although, and, when, which, it, though, where,
# Nearest to many: some, several, these, all, other, themselves, their, various,
# Nearest to up: him, tradeoff, cession, off, them, conceptually, back, either,
# Nearest to who: he, which, they, she, hump, it, frodo, thabit,
# Nearest to on: upon, in, from, during, into, at, endeavours, alejandro,
# Nearest to s: his, brides, stubborn, blackboard, cos, discrepancies, sacrum, and,
# Nearest to for: with, when, without, of, from, by, braganza, after,
# Nearest to as: hass, ideology, with, under, by, racetrack, became, hatta,
# Average loss at step 32000: 3.499075
# Average loss at step 34000: 3.490737
# Average loss at step 36000: 3.457384
# Average loss at step 38000: 3.303536
# Average loss at step 40000: 3.430565
# Nearest to system: resources, systems, theory, maroon, paradise, semitism, pitch, cooperstown,
# Nearest to a: the, or, any, another, incisors, this, comm, pantera,
# Nearest to were: are, was, have, had, be, being, been, mom,
# Nearest to two: three, four, five, seven, six, one, eight, nine,
# Nearest to or: and, than, a, fantasy, ilyich, oleg, partial, loti,
# Nearest to that: which, this, however, what, refreshed, it, who, bernardi,
# Nearest to their: his, its, her, the, some, any, these, infections,
# Nearest to into: from, through, courthouse, across, kor, regarding, kinshasa, compaor,
# Nearest to but: however, and, although, though, it, which, while, are,
# Nearest to many: some, several, these, various, those, all, most, numerous,
# Nearest to up: him, them, off, tradeoff, cession, conceptually, out, back,
# Nearest to who: which, he, often, she, they, also, that, previously,
# Nearest to on: upon, at, during, in, reassured, against, consistory, denigrating,
# Nearest to s: his, our, perkin, cum, brides, charlie, escorts, affleck,
# Nearest to for: by, when, using, in, nez, of, herse, after,
# Nearest to as: ideology, atil, legates, by, when, recumbent, fumes, replicas,
# Average loss at step 42000: 3.437459
# Average loss at step 44000: 3.451757
# Average loss at step 46000: 3.451240
# Average loss at step 48000: 3.352109
# Average loss at step 50000: 3.384251
# Nearest to system: systems, resources, maroon, paradise, caldera, theory, semitism, lauderdale,
# Nearest to a: the, another, any, no, incisors, salzburg, ivar, hearted,
# Nearest to were: are, was, have, be, had, been, is, mom,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to or: and, than, oleg, while, soaemias, rothbard, but, fantasy,
# Nearest to that: which, however, what, this, bushmen, almagro, disposed, but,
# Nearest to their: its, his, her, the, these, several, rajendra, whose,
# Nearest to into: through, from, across, under, courthouse, within, regarding, after,
# Nearest to but: however, although, while, though, and, when, investigators, which,
# Nearest to many: some, several, these, various, both, those, numerous, most,
# Nearest to up: off, him, them, down, out, back, cession, conceptually,
# Nearest to who: which, he, she, they, also, previously, repackaged, have,
# Nearest to on: upon, in, at, through, from, endeavours, within, aloe,
# Nearest to s: whose, blackboard, skeletal, apologetics, ordovician, but, recordings, their,
# Nearest to for: while, herse, without, concealing, irritant, including, kahan, hive,
# Nearest to as: nnhilde, instability, armadillo, evidently, luxemburg, owe, bru, ideology,
# Average loss at step 52000: 3.436802
# Average loss at step 54000: 3.427916
# Average loss at step 56000: 3.439673
# Average loss at step 58000: 3.394714
# Average loss at step 60000: 3.394512
# Nearest to system: systems, resources, application, alkene, software, theory, pitch, contractors,
# Nearest to a: another, the, any, orfeo, incisors, every, bloomsbury, hearted,
# Nearest to were: are, was, have, had, including, been, although, those,
# Nearest to two: four, three, five, six, one, eight, seven, nine,
# Nearest to or: and, than, soaemias, sucking, nailed, non, gojoseon, while,
# Nearest to that: which, what, however, this, it, who, refreshed, hamster,
# Nearest to their: its, his, her, the, ratites, your, these, olin,
# Nearest to into: through, from, within, across, under, adjusted, kor, regarding,
# Nearest to but: however, although, and, when, though, while, which, than,
# Nearest to many: some, several, various, these, both, other, most, all,
# Nearest to up: off, down, him, back, out, them, cession, conceptually,
# Nearest to who: which, he, still, they, she, frodo, previously, both,
# Nearest to on: upon, in, through, offences, conceptualization, at, within, anemometer,
# Nearest to s: whose, blackboard, ciudad, piraeus, warranties, sandwiched, niacin, sacrum,
# Nearest to for: including, of, in, braganza, treeless, herse, serialised, rhenish,
# Nearest to as: when, fanciful, freelance, after, equalled, mounting, isometric, likewise,
# Average loss at step 62000: 3.244119
# Average loss at step 64000: 3.252446
# Average loss at step 66000: 3.403898
# Average loss at step 68000: 3.397188
# Average loss at step 70000: 3.360937
# Nearest to system: systems, alkene, resources, pitch, goldsmith, software, theory, maroon,
# Nearest to a: the, another, any, hearted, its, spectrometer, this, their,
# Nearest to were: are, was, have, had, be, including, been, although,
# Nearest to two: three, four, six, seven, one, five, eight, zero,
# Nearest to or: and, than, while, eighties, thrax, the, any, ru,
# Nearest to that: which, what, however, this, but, gentoo, often, almagro,
# Nearest to their: its, his, her, the, your, these, whose, my,
# Nearest to into: through, from, within, across, under, towards, kor, hern,
# Nearest to but: however, although, though, which, while, and, when, than,
# Nearest to many: some, several, various, all, these, most, numerous, both,
# Nearest to up: off, down, back, out, them, cession, him, help,
# Nearest to who: he, which, still, frodo, they, she, generally, yapese,
# Nearest to on: upon, through, in, within, anemometer, at, under, during,
# Nearest to s: whose, perkin, blackboard, lsd, our, his, preoccupations, hypostasis,
# Nearest to for: in, including, of, by, herse, to, without, when,
# Nearest to as: spores, like, by, when, runequest, describe, owe, marriageable,
# Average loss at step 72000: 3.372433
# Average loss at step 74000: 3.349768
# Average loss at step 76000: 3.314459
# Average loss at step 78000: 3.348093
# Average loss at step 80000: 3.378814
# Nearest to system: systems, goldsmith, resources, pitch, controller, hemorrhage, theory, software,
# Nearest to a: another, incisors, pantera, the, vertebra, every, ced, ghola,
# Nearest to were: are, was, had, have, been, being, be, became,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to or: and, than, while, non, pulsed, ru, rothbard, but,
# Nearest to that: which, however, this, where, hypocrites, longfellow, why, what,
# Nearest to their: its, his, her, your, the, my, our, these,
# Nearest to into: through, from, across, within, under, towards, kor, hern,
# Nearest to but: however, although, though, while, which, see, than, and,
# Nearest to many: some, several, various, both, all, these, numerous, most,
# Nearest to up: off, down, out, them, back, him, conceptually, cession,
# Nearest to who: he, they, which, still, she, often, usually, frodo,
# Nearest to on: upon, in, at, through, during, protea, against, under,
# Nearest to s: isbn, imp, correspondingly, whose, blackboard, ciudad, dhea, perkin,
# Nearest to for: herse, including, troglodytes, gundestrup, inverted, prime, against, mri,
# Nearest to as: atil, jill, telekinetic, safari, showcasing, carnal, puppies, underestimated,
# Average loss at step 82000: 3.410295
# Average loss at step 84000: 3.408606
# Average loss at step 86000: 3.389792
# Average loss at step 88000: 3.351253
# Average loss at step 90000: 3.367383
# Nearest to system: systems, pitch, theory, controller, resources, blocks, insufficiency, game,
# Nearest to a: the, hearted, another, ramones, ced, every, any, outstanding,
# Nearest to were: are, had, was, have, while, although, been, rhead,
# Nearest to two: three, four, five, seven, six, one, eight, nine,
# Nearest to or: and, rothbard, soaemias, but, while, than, utilitarian, baltasar,
# Nearest to that: which, however, what, but, almagro, lyra, certainly, exterminated,
# Nearest to their: its, his, her, your, our, the, my, whose,
# Nearest to into: through, from, across, within, down, kor, under, blanket,
# Nearest to but: however, although, and, while, though, which, that, until,
# Nearest to many: some, several, these, various, all, both, numerous, most,
# Nearest to up: off, out, down, back, them, him, cession, conceptually,
# Nearest to who: he, still, she, often, they, which, generally, also,
# Nearest to on: upon, under, through, at, in, during, within, darlington,
# Nearest to s: whose, isbn, his, our, perkin, castell, necrosis, dhea,
# Nearest to for: including, of, while, herse, berserker, hive, after, irritant,
# Nearest to as: like, shine, showcasing, telekinetic, atil, erick, grove, grossly,
# Average loss at step 92000: 3.400942
# Average loss at step 94000: 3.253796
# Average loss at step 96000: 3.361847
# Average loss at step 98000: 3.239935
# Average loss at step 100000: 3.360913
# Nearest to system: systems, resources, lilac, controller, process, software, goldsmith, layout,
# Nearest to a: another, the, any, hearted, incisors, ced, ramones, counted,
# Nearest to were: are, was, have, had, although, including, dosages, these,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to or: and, than, pulsed, per, tape, photographic, while, seimas,
# Nearest to that: which, however, what, but, sarasota, bushmen, disposed, this,
# Nearest to their: its, his, her, your, our, the, several, my,
# Nearest to into: through, across, within, from, in, under, hern, down,
# Nearest to but: however, although, and, though, while, which, that, strives,
# Nearest to many: some, several, various, these, numerous, all, those, syst,
# Nearest to up: off, out, back, down, him, them, leakage, cession,
# Nearest to who: he, still, which, she, actually, generally, often, also,
# Nearest to on: upon, in, through, at, within, against, during, under,
# Nearest to s: whose, his, perkin, sarah, blackboard, chia, our, probate,
# Nearest to for: when, after, including, berserker, while, without, hive, monomer,
# Nearest to as: like, governs, likewise, fanciful, by, armadillo, racetrack, marriageable,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ### Problem
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %% [markdown]
# ![word2vec](cbow.jpg)
#
# CBOW inverts the dataset in a way, now we predict a word given the surrounding ones. Since each word in the surrounding context has its own word vector, we sum them into one context embedding and the process continues as before

# %%
data_index = 0 # this variable acts a a global pointer to the data array. 

def generate_batch_cbow(batch_size, context_window_size):
  global data_index
  batch = np.ndarray(shape=(batch_size, 2*context_window_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  
  span = 2 * context_window_size + 1 # [ context_window label context_window ]
  buffer = collections.deque(maxlen=span) # sliding window to be moved over the whole data array
  # fill the buffer with the first words from the current window (span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data) # modulo just in case we get to the end of the data array
  for i in range(batch_size):
    target = context_window_size  # target label at the center of the buffer
    window = []
    for j in range(span):
      if j != target:
        window.append(buffer[j])
    batch[i] = np.array(window)
    labels[i, 0] = buffer[target] # we add the label to be predicted
    # let's move the sliding window one word to the right
    buffer.append(data[data_index]) # push one in to the back of the queue, the first in the queue pops out
    data_index = (data_index + 1) % len(data)
  return batch, labels

# remember, data contains the keys (indexes of words the in original words string) of common 
# words in the reverse dictionary
print('data:', [reverse_dictionary[di] for di in data[:8]])

# some examples of skipgram datasets
for context_window_size in [2, 4]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, context_window_size=context_window_size)
    print('\nwith context_window_size = %d:' % (context_window_size))
    print('    batch:', [[reverse_dictionary[bi] for bi in b] for b in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with context_window_size = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with context_window_size = 4:
#     batch: [['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used'], ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against'], ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early'], ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working'], ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class'], ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals'], ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including'], ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']]
#     labels: ['term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']

# %% [markdown]
# Train a CBOW model

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window_size = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*context_window_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # This method is used similar to fancy indexing in numpy. train_dataset is a list of indexes
  # representing the rows to be retrieved from the embeddings 2D tensor. The embedding vectors are concatenated
  # into a dense tensor of shape (batch_size x context_window_size x embedding_size)
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # And now according to CBOW, we sum all the embedding vectors to obtain a context embedding
  sum_embed = tf.reduce_sum(embed, 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  # sum_embed is a tensor with shape (batch_size x embedding_size)
  # weights is tensor with shape (vocabulary_size x embedding_size)
  # so I guess what happens below is that embed gets transposed so the shapes match for multiplication
  # output = softmax_weights * sum_embed.T + softmax_biases
  # output is a tensor with shape (vocabulary_size x batch size), i.e. one output column 
  # (probability distribution over the vocabulary) per input word
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=sum_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, context_window_size)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.040525
# Nearest to new: aptitude, keywork, postmodernist, hobart, thus, twilight, uploads, crannog,
# Nearest to but: recruiting, neu, disproving, manned, mercantilists, decimus, khanty, overkill,
# Nearest to th: flooding, foreknowledge, milligan, depopulated, grosse, unconfirmed, terra, harmonious,
# Nearest to one: ritter, romulus, implosive, ethidium, sibilants, remarking, catering, crick,
# Nearest to for: cantigas, perpetuation, clemens, rococo, egg, barns, dumbarton, associative,
# Nearest to these: enrollments, acute, visa, massacre, esas, bashir, intensification, coolidge,
# Nearest to system: narcolepsy, angora, dayan, tertium, pci, leetspeak, homosexual, animalium,
# Nearest to often: tripartite, hellas, representationalism, invited, lets, klansmen, savile, pantheon,
# Nearest to from: canning, logicians, gateless, thief, bakunin, surpass, bongo, evaporation,
# Nearest to was: alternately, excitable, heaney, vibrato, tights, official, harford, tore,
# Nearest to at: isin, denounced, experiences, classified, mediating, elaborating, ser, augmented,
# Nearest to b: fad, pylons, wallonia, fz, typically, gymnasium, morales, libi,
# Nearest to united: triadic, folktales, forfeited, essene, reassert, ortelius, tiryns, displeasure,
# Nearest to into: mob, heeled, stops, techs, brit, naval, many, intuition,
# Nearest to as: yogi, heaps, linnaean, ruthenia, quebec, psa, oriole, selby,
# Nearest to two: mold, annihilation, comet, round, readers, supervisor, wgn, blackbody,
# Average loss at step 2000: 4.586916
# Average loss at step 4000: 3.836130
# Average loss at step 6000: 3.785736
# Average loss at step 8000: 3.705889
# Average loss at step 10000: 3.571351
# Nearest to new: wicklow, humble, aptitude, dysentery, kc, plume, scott, wynette,
# Nearest to but: however, although, since, before, and, using, overhauled, brisk,
# Nearest to th: nine, diabetics, eight, rer, milligan, montreal, abdu, blenheim,
# Nearest to one: swims, arianism, bbci, tammany, choi, ceos, renaming, potomac,
# Nearest to for: pulsed, chs, ichthyology, mariano, among, urinate, following, attenuation,
# Nearest to these: some, many, all, other, they, cessna, several, mitochondria,
# Nearest to system: mikado, fencers, shaka, handball, leetspeak, reparation, propellers, heian,
# Nearest to often: usually, tripartite, sometimes, mobilizing, rashad, ethel, diomedea, commonly,
# Nearest to from: into, in, during, at, analyst, elicit, through, eskimos,
# Nearest to was: is, were, became, are, has, had, infidel, gerais,
# Nearest to at: from, videotape, rom, reprisals, incisors, augmented, hier, around,
# Nearest to b: definite, pylons, truso, canoes, fz, ppm, viper, colonels,
# Nearest to united: city, horror, romagna, owl, plundering, dervish, member, nicolas,
# Nearest to into: from, filking, melt, deceased, longed, in, acropolis, seating,
# Nearest to as: atlantean, onions, hats, unhappiness, sheppard, ritter, pulls, ger,
# Nearest to two: nine, five, several, three, eight, zero, vanished, kowalski,
# Average loss at step 12000: 3.447639
# Average loss at step 14000: 3.418932
# Average loss at step 16000: 3.455310
# Average loss at step 18000: 3.392201
# Average loss at step 20000: 3.259635
# Nearest to new: virtues, aptitude, cockburn, comcast, wynette, omnium, sag, dysentery,
# Nearest to but: although, however, when, though, delicacy, harder, almost, arabica,
# Nearest to th: twentieth, classifies, coda, montreal, sore, nine, diabetics, restyled,
# Nearest to one: six, eight, nine, two, three, zero, weezer, mercantilism,
# Nearest to for: without, urinate, ichthyology, before, after, egg, pulsed, following,
# Nearest to these: other, those, many, ventilated, different, their, several, various,
# Nearest to system: mikado, systems, sabha, reparation, shaka, kodansha, bannister, fencers,
# Nearest to often: usually, sometimes, commonly, generally, still, now, bankhead, concomitant,
# Nearest to from: through, into, during, under, in, automata, across, when,
# Nearest to was: is, were, became, had, are, being, has, be,
# Nearest to at: during, near, hier, undifferentiated, mae, shang, galvanic, augmented,
# Nearest to b: f, r, pylons, pcb, morales, tent, sawdust, predisposition,
# Nearest to united: owl, jess, plundering, prospective, british, us, australis, applicants,
# Nearest to into: from, out, through, filking, under, antagonist, deceased, implosion,
# Nearest to as: memetics, onions, commercially, screenings, hats, epilepsy, gaians, authoring,
# Nearest to two: zero, five, one, three, nine, vanished, atheists, ovary,
# Average loss at step 22000: 3.354030
# Average loss at step 24000: 3.268940
# Average loss at step 26000: 3.233143
# Average loss at step 28000: 2.757685
# Average loss at step 30000: 2.939417
# Nearest to new: replenish, microcosm, heliopause, bede, old, hitpa, sighting, virtues,
# Nearest to but: though, although, however, than, while, swallow, tack, unilaterally,
# Nearest to th: twentieth, st, nd, nineteenth, third, classifies, blenheim, antofagasta,
# Nearest to one: yarn, pasquale, pouch, comic, accumulates, detached, transcending, abyssinian,
# Nearest to for: after, mycoplasma, analysed, ichthyology, without, including, pulsed, before,
# Nearest to these: both, various, their, several, other, different, many, certain,
# Nearest to system: systems, bannister, defer, version, rebel, platform, sabha, propellers,
# Nearest to often: sometimes, usually, generally, commonly, still, goguryeo, frequently, widely,
# Nearest to from: into, through, under, neuroimaging, in, cypriot, ralf, speculations,
# Nearest to was: is, became, were, are, had, holds, tutor, csu,
# Nearest to at: near, in, during, undifferentiated, wedded, pittsburgh, around, arexx,
# Nearest to b: d, definite, tortured, planning, pp, tenor, ether, truthful,
# Nearest to united: mitch, us, owl, mandating, earthworks, curtiss, precocious, future,
# Nearest to into: through, from, under, across, out, onto, filking, within,
# Nearest to as: onions, notched, screenings, atlantean, sends, chiropractors, chimpanzee, baird,
# Nearest to two: four, three, five, zero, seven, six, eight, viscount,
# Average loss at step 32000: 3.131802
# Average loss at step 34000: 3.100257
# Average loss at step 36000: 3.207600
# Average loss at step 38000: 3.162890
# Average loss at step 40000: 2.962335
# Nearest to new: single, heliopause, bede, timbuktu, microcosm, ana, kc, different,
# Nearest to but: however, although, and, than, though, see, since, plankton,
# Nearest to th: twentieth, st, nine, nd, nineteenth, third, eight, limitations,
# Nearest to one: proctor, kino, ott, inextricably, two, spo, barnett, leyte,
# Nearest to for: including, menger, languished, ichthyology, analysed, without, thabit, kilkenny,
# Nearest to these: different, various, many, those, some, their, mathura, washing,
# Nearest to system: systems, lax, hectic, intercity, defer, telharmonium, sabha, network,
# Nearest to often: sometimes, usually, generally, commonly, still, widely, typically, now,
# Nearest to from: through, into, plc, without, under, gv, enlightened, via,
# Nearest to was: is, became, being, were, had, becomes, holds, has,
# Nearest to at: during, near, since, predated, wedded, around, roost, in,
# Nearest to b: d, om, p, affirming, n, f, copps, stabilised,
# Nearest to united: owl, us, mitch, league, yard, future, british, bellum,
# Nearest to into: through, from, across, onto, down, out, over, within,
# Nearest to as: onions, atlantean, tib, nicknames, geometries, hawthorn, descends, notched,
# Nearest to two: three, four, five, seven, six, zero, several, nine,
# Average loss at step 42000: 3.125530
# Average loss at step 44000: 3.160664
# Average loss at step 46000: 3.138858
# Average loss at step 48000: 2.808571
# Average loss at step 50000: 3.000621
# Nearest to new: heliopause, bede, different, simple, replenish, microcosm, spearhead, comcast,
# Nearest to but: however, and, or, although, though, propagated, separating, while,
# Nearest to th: twentieth, nd, third, nineteenth, st, rd, nine, only,
# Nearest to one: chipmunks, overhaul, longrightarrow, order, dci, forks, flue, wiping,
# Nearest to for: after, before, pulsed, without, mycoplasma, analysed, kilkenny, fuelled,
# Nearest to these: other, various, those, different, certain, additional, eradicating, schwarzenegger,
# Nearest to system: systems, district, defer, bannister, network, platform, encyclopaedia, sabha,
# Nearest to often: usually, generally, sometimes, commonly, typically, still, frequently, widely,
# Nearest to from: under, into, using, gv, through, across, via, appel,
# Nearest to was: is, were, became, are, had, becomes, makes, be,
# Nearest to at: near, during, around, foiled, in, messe, hier, tansley,
# Nearest to b: d, privatize, branch, quarto, cbe, fang, aspiration, contemporaries,
# Nearest to united: mitch, us, yard, owl, danish, neighboring, cretinism, precocious,
# Nearest to into: onto, through, out, from, within, filking, under, down,
# Nearest to as: authoring, sublimation, onions, lillee, sends, underdog, chording, radiator,
# Nearest to two: three, four, five, six, eight, seven, zero, thrower,
# Average loss at step 52000: 2.926196
# Average loss at step 54000: 3.084785
# Average loss at step 56000: 2.965538
# Average loss at step 58000: 3.079312
# Average loss at step 60000: 3.035248
# Nearest to new: simple, replenish, bede, heliopause, nepotism, particular, spearhead, histogram,
# Nearest to but: and, though, alaskan, than, basing, escuela, sharia, offerings,
# Nearest to th: nd, twentieth, nineteenth, third, nine, st, rd, pederastic,
# Nearest to one: casement, chipmunks, housman, two, dong, mosquitia, ligature, hmong,
# Nearest to for: of, alde, including, ichthyology, without, brava, after, if,
# Nearest to these: various, those, examples, different, goidelic, reunified, mathura, several,
# Nearest to system: systems, branch, program, version, alemannic, bannister, district, linearly,
# Nearest to often: usually, sometimes, generally, commonly, frequently, widely, typically, rarely,
# Nearest to from: into, through, via, in, surpass, across, between, appel,
# Nearest to was: is, became, were, becomes, had, makes, holds, being,
# Nearest to at: during, near, kaluza, mae, undifferentiated, augmented, wedded, airtight,
# Nearest to b: d, solves, edomites, overthrew, businessman, manoeuvre, watercolor, widening,
# Nearest to united: us, worst, mitch, departing, photosphere, buffet, deepen, future,
# Nearest to into: through, onto, from, within, across, out, under, beyond,
# Nearest to as: authoring, hats, glowing, radiator, tenerife, chording, underdog, onions,
# Nearest to two: three, four, eight, six, five, bakersfield, seven, username,
# Average loss at step 62000: 3.003405
# Average loss at step 64000: 2.951953
# Average loss at step 66000: 2.927765
# Average loss at step 68000: 2.881525
# Average loss at step 70000: 2.962296
# Nearest to new: simple, single, particular, heliopause, certain, large, histogram, bede,
# Nearest to but: however, though, see, and, although, almost, chd, tasking,
# Nearest to th: nd, twentieth, third, nineteenth, rd, eighteenth, st, blenheim,
# Nearest to one: meir, ddo, unwelcome, ligature, saviola, fireman, tennant, mediating,
# Nearest to for: including, melinda, brava, tomcats, during, gave, before, of,
# Nearest to these: various, several, major, other, numerous, dozens, different, revere,
# Nearest to system: systems, bannister, version, branch, detectable, concept, defer, capability,
# Nearest to often: sometimes, generally, usually, commonly, frequently, typically, widely, rarely,
# Nearest to from: via, through, into, appel, across, before, ralf, plc,
# Nearest to was: is, were, became, becomes, are, had, involves, being,
# Nearest to at: during, near, messe, upon, roost, wikimedia, predated, kaunda,
# Nearest to b: d, unexpectedly, edomites, pai, businessman, staffing, slice, cbe,
# Nearest to united: worst, neighboring, horror, future, confederate, mitch, imparting, owl,
# Nearest to into: onto, through, within, from, out, across, filking, over,
# Nearest to as: onions, underdog, authoring, gesture, remarkably, antipathy, chimpanzee, too,
# Nearest to two: three, four, six, five, isbn, eight, intramolecular, secretly,
# Average loss at step 72000: 2.937321
# Average loss at step 74000: 2.974908
# Average loss at step 76000: 2.953498
# Average loss at step 78000: 2.817997
# Average loss at step 80000: 2.963940
# Nearest to new: heliopause, simple, microcosm, particular, comcast, bede, hew, orion,
# Nearest to but: however, though, although, and, while, there, almost, than,
# Nearest to th: nd, st, twentieth, third, nineteenth, next, rd, blenheim,
# Nearest to one: casement, three, two, ddo, inhalation, fac, cavalrymen, ghul,
# Nearest to for: mycoplasma, without, menger, alde, of, salary, including, agape,
# Nearest to these: some, various, numerous, many, certain, those, clint, several,
# Nearest to system: systems, program, platform, bannister, branch, unit, project, version,
# Nearest to often: usually, sometimes, generally, frequently, typically, commonly, widely, rarely,
# Nearest to from: through, via, into, across, between, plc, in, reconsideration,
# Nearest to was: is, were, became, becomes, remained, are, had, involves,
# Nearest to at: during, predated, wedded, fd, roost, magazine, hypothalamus, around,
# Nearest to b: d, compartment, letter, manoeuvre, r, f, gish, assess,
# Nearest to united: us, imparting, exp, worst, owl, brain, confederate, neighboring,
# Nearest to into: onto, through, within, across, from, in, beyond, between,
# Nearest to as: onions, authoring, hats, aussie, underdog, lillee, zander, supplant,
# Nearest to two: three, four, five, eight, zero, one, six, davison,
# Average loss at step 82000: 2.972252
# Average loss at step 84000: 2.926726
# Average loss at step 86000: 2.967701
# Average loss at step 88000: 2.923422
# Average loss at step 90000: 2.794624
# Nearest to new: bede, simple, particular, complicate, scraps, heliopause, historiography, suiko,
# Nearest to but: however, although, though, and, see, or, until, caracalla,
# Nearest to th: twentieth, nd, third, st, nineteenth, blenheim, tenth, fifteenth,
# Nearest to one: two, terms, jehoash, gator, tutoring, casement, geckos, obfuscated,
# Nearest to for: without, css, after, toward, agape, of, pulsed, brava,
# Nearest to these: various, those, which, whose, numerous, they, major, earnestly,
# Nearest to system: systems, program, branch, version, concept, company, network, platform,
# Nearest to often: sometimes, frequently, usually, commonly, generally, widely, typically, still,
# Nearest to from: via, into, through, across, plc, appel, haggis, xaf,
# Nearest to was: is, were, becomes, became, are, remains, has, had,
# Nearest to at: near, fd, wedded, predated, contravening, in, within, mem,
# Nearest to b: d, f, auditioning, r, k, compartment, c, widening,
# Nearest to united: exp, danish, imparting, neighboring, rodin, us, deepen, owl,
# Nearest to into: through, onto, within, from, across, beyond, out, between,
# Nearest to as: onions, authoring, hats, became, unacceptably, underdog, recursively, kensington,
# Nearest to two: three, one, haken, nine, four, zero, seven, five,
# Average loss at step 92000: 2.840075
# Average loss at step 94000: 2.909799
# Average loss at step 96000: 2.893342
# Average loss at step 98000: 2.913881
# Average loss at step 100000: 2.950505
# Nearest to new: bede, simple, heliopause, particular, microcosm, old, pirate, uploads,
# Nearest to but: although, however, though, while, than, unlike, and, until,
# Nearest to th: nd, st, twentieth, third, rd, nineteenth, tenth, sore,
# Nearest to one: two, meir, casement, jehoash, kwazulu, jehoiachin, ligature, uncharacteristically,
# Nearest to for: including, pulsed, against, brava, mycoplasma, after, agape, sayyid,
# Nearest to these: various, special, several, additional, those, multiple, there, which,
# Nearest to system: systems, program, model, concept, platform, branch, fraunhofer, encyclopaedia,
# Nearest to often: frequently, generally, commonly, sometimes, typically, usually, widely, actually,
# Nearest to from: via, across, through, into, within, in, between, on,
# Nearest to was: is, were, became, becomes, remains, had, venturing, makes,
# Nearest to at: near, in, mem, fd, wedded, during, piss, inside,
# Nearest to b: d, binary, r, k, c, davidic, f, definite,
# Nearest to united: us, confederate, addition, worst, erodes, mitch, aegean, u,
# Nearest to into: onto, through, within, across, out, from, beyond, between,
# Nearest to as: chimpanzee, how, remarkably, like, authoring, alger, mandates, sublimation,
# Nearest to two: three, four, five, haken, nine, several, six, one,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
